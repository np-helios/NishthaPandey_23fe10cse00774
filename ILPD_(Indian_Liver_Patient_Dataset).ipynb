# %% [markdown]
# <a href="https://colab.research.google.com/github/np-helios/NishthaPandey_23fe10cse00774/blob/main/ILPD_(Indian_Liver_Patient_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00225/Indian%20Liver%20Patient%20Dataset%20(ILPD).csv"

df = pd.read_csv(url, header=None)

df.columns = [
    "Age", "Gender", "Total_Bilirubin", "Direct_Bilirubin",
    "Alkaline_Phosphotase", "Alamine_Aminotransferase",
    "Aspartate_Aminotransferase", "Total_Proteins",
    "Albumin", "Albumin_Globulin_Ratio", "Selector"
]

df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_Globulin_Ratio  Selector
# 0      3.3                    0.90         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Proteins              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_Globulin_Ratio      579 non-null    float64
#  10  Selector                    583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Proteins', 'Albumin',
#        'Albumin_Globulin_Ratio', 'Selector'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
print(df.isnull().sum())
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Proteins                0
# Albumin                       0
# Albumin_Globulin_Ratio        4
# Selector                      0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Proteins                float64
# Albumin                       float64
# Albumin_Globulin_Ratio        float64
# Selector                        int64
# dtype: object

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

fig, axs = plt.subplots(len(numeric_df.columns), 1, figsize=(20, 31), dpi=95)

for i, col in enumerate(numeric_df.columns):
    axs[i].boxplot(numeric_df[col], vert=False)
    axs[i].set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
for col in df.columns:
    print(f"\n{col}")
    print(df[col].unique())
# Out:
# Age
# [65 62 58 72 46 26 29 17 55 57 64 74 61 25 38 33 40 51 63 34 20 84 52 30
#  48 47 45 42 50 85 35 21 32 31 54 37 66 60 19 75 68 70 49 14 13 18 39 27
#  36 24 28 53 15 56 44 41  7 22  8  6  4 43 23 12 69 16 78 11 73 67 10 90]
#
# Gender
# ['Female' 'Male']
#
# Total_Bilirubin
# [ 0.7 10.9  7.3  1.   3.9  1.8  0.9  0.6  2.7  1.1  1.6  2.2  2.9  6.8
#   1.9  4.1  6.2  4.   2.6  1.3 14.2  1.4  2.4 18.4  3.1  8.9  0.8  2.8
#   2.   5.7  8.6  5.8  5.2  3.8  6.6  0.5  5.3  3.2  1.2 12.7 15.9 18.
#  23.  22.7  1.7  3.  11.3  4.7  4.2  3.5  5.9  8.7 11.  11.5  4.5 75.
#  22.8 14.1 14.8 10.6  8.   1.5  2.1  6.3  2.3 27.2  2.5  3.6 30.5 16.4
#  14.5 18.5 23.2  3.7  3.3  7.1  6.7 22.6  7.5  5.   4.9  8.2  0.4  7.4
#  23.3  7.9  3.4 19.8 32.6 17.7 20.  26.3  4.4  9.4 30.8 19.6 15.8  5.5
#  20.2 27.7 11.1 10.2 42.8 15.2 16.6 17.3 22.5 16.7  7.7 15.6 12.1 25.
#  15. ]
#
# Direct_Bilirubin
# [ 0.1  5.5  4.1  0.4  2.   0.7  0.2  0.3  1.3  0.8  0.5  1.   3.   1.9
# ...

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# df['Gender'] = le.fit_transform(df['Gender'])

# %%
df['Gender'] = df['Gender'].map({
    'Male': 1,
    'Female': 0
})

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                          int64
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Proteins                float64
# Albumin                       float64
# Albumin_Globulin_Ratio        float64
# Selector                        int64
# dtype: object

# %%
continuous_cols = [
    'Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
       'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
       'Aspartate_Aminotransferase', 'Total_Proteins', 'Albumin',
       'Albumin_Globulin_Ratio', 'Selector'
]

outlier_counts = {}

for col in continuous_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]
    outlier_counts[col] = len(outliers)

pd.DataFrame.from_dict(outlier_counts, orient='index', columns=['Outlier_Count']) \
  .sort_values(by='Outlier_Count', ascending=False)
# Out:
#                             Outlier_Count
# Gender                                142
# Total_Bilirubin                        84
# Direct_Bilirubin                       81
# Alamine_Aminotransferase               73
# Alkaline_Phosphotase                   69
# Aspartate_Aminotransferase             66
# Albumin_Globulin_Ratio                 10
# Total_Proteins                          8
# Age                                     0
# Albumin                                 0
# Selector                                0

# %%
df[continuous_cols].dtypes
# Out:
# Age                             int64
# Gender                          int64
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Proteins                float64
# Albumin                       float64
# Albumin_Globulin_Ratio        float64
# Selector                        int64
# dtype: object

# %%
corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(16, 18), dpi=120)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
df['Gender_log'] = np.log1p(df['Gender'])
df['Total_Bilirubin_log'] = np.log1p(df['Total_Bilirubin'])
df['Direct_Bilirubin_log'] = np.log1p(df['Direct_Bilirubin'])
df['Alkaline_Phosphotase_log'] = np.log1p(df['Alkaline_Phosphotase'])
df['Alamine_Aminotransferase_log'] = np.log1p(df['Alamine_Aminotransferase'])

# %%
from sklearn.preprocessing import MinMaxScaler
X = df[
    [
        'Gender_log',
        'Total_Bilirubin_log',
        'Direct_Bilirubin_log',
        'Alkaline_Phosphotase_log',
        'Alamine_Aminotransferase_log'
    ]
]

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
print(X_normalized[:5])
# Out:
# [[0.         0.04860874 0.         0.30822323 0.08365859]
#  [1.         0.53578524 0.60531476 0.6842603  0.34140282]
#  [1.         0.44558511 0.52266528 0.58282072 0.32919694]
#  [1.         0.08929685 0.08217259 0.30051283 0.05960498]
#  [1.         0.31364073 0.34186114 0.32014322 0.17955376]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)
print(X_standardized[:5])
# Out:
# [[-1.76228085 -0.70831605 -0.78126743 -0.49740368 -1.07518908]
#  [ 0.56744644  1.92720554  1.92628226  2.00251224  0.44396825]
#  [ 0.56744644  1.43924194  1.55659431  1.32813614  0.37202616]
#  [ 0.56744644 -0.48820201 -0.41371258 -0.54866284 -1.21696227]
#  [ 0.56744644  0.72545081  0.74786432 -0.41815889 -0.5099782 ]]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(X_normalized[:, 0], X_normalized[:, 1])
plt.xlabel("Total_Bilirubin_log (normalized)")
plt.ylabel("Direct_Bilirubin_log (normalized)")
plt.title("Outlier / Error Check")
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_Globulin_Ratio  Selector  Gender_log  Total_Bilirubin_log  \
# ...

# %%
l_column = list(df.columns) # Making a list out of column names
len_feature = len(l_column) # Length of column vector list
l_column
# Out:
# ['Age',
#  'Gender',
#  'Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Total_Proteins',
#  'Albumin',
#  'Albumin_Globulin_Ratio',
#  'Selector',
#  'Gender_log',
#  'Total_Bilirubin_log',
#  'Direct_Bilirubin_log',
#  'Alkaline_Phosphotase_log',
#  'Alamine_Aminotransferase_log']

# %%
X = df[l_column[1:len_feature]]
y = df[l_column[0]]

# %%
print("Feature set size:",X.shape)
print("Variable set size:",y.shape)
# Out:
# Feature set size: (583, 15)
# Variable set size: (583,)

# %%
X.head()
# Out:
#    Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0       0              0.7               0.1                   187
# 1       1             10.9               5.5                   699
# 2       1              7.3               4.1                   490
# 3       1              1.0               0.4                   182
# 4       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_Globulin_Ratio  Selector  Gender_log  Total_Bilirubin_log  \
# ...

# %%
y.head()
# Out:
# 0    65
# 1    62
# 2    62
# 3    58
# 4    72
# Name: Age, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                            test_size=0.3, random_state=123)

# %%
print("Training feature set size:",X_train.shape)
print("Test feature set size:",X_test.shape)
print("Training variable set size:",y_train.shape)
print("Test variable set size:",y_test.shape)
# Out:
# Training feature set size: (408, 15)
# Test feature set size: (175, 15)
# Training variable set size: (408,)
# Test variable set size: (175,)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("NaNs in X_train:", np.isnan(X_train).sum())
print("NaNs in y_train:", np.isnan(y_train).sum())
# Out:
# X_train shape: (408, 15)
# y_train shape: (408,)
# NaNs in X_train: Gender                          0
# Total_Bilirubin                 0
# Direct_Bilirubin                0
# Alkaline_Phosphotase            0
# Alamine_Aminotransferase        0
# Aspartate_Aminotransferase      0
# Total_Proteins                  0
# Albumin                         0
# Albumin_Globulin_Ratio          3
# Selector                        0
# Gender_log                      0
# Total_Bilirubin_log             0
# Direct_Bilirubin_log            0
# Alkaline_Phosphotase_log        0
# Alamine_Aminotransferase_log    0
# dtype: int64
# NaNs in y_train: 0

# %%
import numpy as np
print("Inf in X_train:", np.isinf(X_train).sum())
print("Inf in y_train:", np.isinf(y_train).sum())
print("Non-finite in X_train:", ~np.isfinite(X_train).sum())
print("Non-finite in y_train:", ~np.isfinite(y_train).sum())
# Out:
# Inf in X_train: Gender                          0
# Total_Bilirubin                 0
# Direct_Bilirubin                0
# Alkaline_Phosphotase            0
# Alamine_Aminotransferase        0
# Aspartate_Aminotransferase      0
# Total_Proteins                  0
# Albumin                         0
# Albumin_Globulin_Ratio          0
# Selector                        0
# Gender_log                      0
# Total_Bilirubin_log             0
# Direct_Bilirubin_log            0
# Alkaline_Phosphotase_log        0
# Alamine_Aminotransferase_log    0
# dtype: int64
# Inf in y_train: 0
# Non-finite in X_train: Gender                         -409
# Total_Bilirubin                -409
# Direct_Bilirubin               -409
# Alkaline_Phosphotase           -409
# Alamine_Aminotransferase       -409
# Aspartate_Aminotransferase     -409
# Total_Proteins                 -409
# Albumin                        -409
# Albumin_Globulin_Ratio         -406
# Selector                       -409
# ...

# %%
non_finite_mask = ~np.isfinite(y_train)
print("Non-finite rows in y_train:", np.where(non_finite_mask)[0])
print("Non-finite values:", y_train[non_finite_mask])
# Out:
# Non-finite rows in y_train: []
# Non-finite values: Series([], Name: Age, dtype: int64)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lm = LinearRegression()

# %%
finite_mask = np.isfinite(y_train)
y_mean = np.mean(y_train[finite_mask])
X_mean = np.mean(X_train[finite_mask])
y_train_fixed = np.where(np.isfinite(y_train), y_train, y_mean)
X_train_fixed = np.where(np.isfinite(X_train), X_train, X_mean)
# Now fit
model = LinearRegression()
model.fit(X_train_fixed, y_train_fixed)
# Out:
# LinearRegression()

# %%
print("The intercept term of the linear model:", model.intercept_)
print("The coefficients of the linear model:", model.coef_)
# Out:
# The intercept term of the linear model: 88.26260650603481
# The coefficients of the linear model: [ 6.42648584e-01 -6.01237915e-01 -9.40075555e-01  1.38079595e-02
#  -7.62344185e-03  3.09643874e-03  1.14230829e+00 -6.25881330e+00
#  -1.40561895e-01 -4.41151706e+00  4.45450054e-01  1.72152399e+01
#  -1.14788358e+01 -6.14396674e+00 -9.66585442e-01]

# %%
cdf = pd.DataFrame(data=model.coef_, index=X_train.columns, columns=["Coefficients"])
#cdf=pd.concat([idf,cdf], axis=0)
cdf
# Out:
#                               Coefficients
# Gender                            0.642649
# Total_Bilirubin                  -0.601238
# Direct_Bilirubin                 -0.940076
# Alkaline_Phosphotase              0.013808
# Alamine_Aminotransferase         -0.007623
# Aspartate_Aminotransferase        0.003096
# Total_Proteins                    1.142308
# Albumin                          -6.258813
# Albumin_Globulin_Ratio           -0.140562
# Selector                         -4.411517
# Gender_log                        0.445450
# Total_Bilirubin_log              17.215240
# Direct_Bilirubin_log            -11.478836
# Alkaline_Phosphotase_log         -6.143967
# Alamine_Aminotransferase_log     -0.966585

# %%
n=X_train_fixed.shape[0]
k=X_train_fixed.shape[1]
dfN = n-k
train_pred=model.predict(X_train_fixed)
train_error = np.square(train_pred - y_train_fixed)
sum_error=np.sum(train_error)
se=[0]*k
for i in range(k):
    r = (sum_error/dfN)
    r = r/np.sum(np.square(X_train_fixed[:, i]-X_train_fixed[:, i].mean()))
    se[i]=np.sqrt(r)
cdf['Standard Error']=se
cdf['t-statistic']=cdf['Coefficients']/cdf['Standard Error']
cdf
# Out:
#                               Coefficients  Standard Error  t-statistic
# Gender                            0.642649        1.808474     0.355354
# Total_Bilirubin                  -0.601238        0.143694    -4.184153
# Direct_Bilirubin                 -0.940076        0.282609    -3.326423
# Alkaline_Phosphotase              0.013808        0.002966     4.655504
# Alamine_Aminotransferase         -0.007623        0.004019    -1.896885
# Aspartate_Aminotransferase        0.003096        0.002393     1.293960
# Total_Proteins                    1.142308        0.693157     1.647978
# Albumin                          -6.258813        0.963644    -6.494943
# Albumin_Globulin_Ratio           -0.140562        0.270659    -0.519332
# Selector                         -4.411517        1.679582    -2.626557
# Gender_log                        0.445450        2.609077     0.170731
# Total_Bilirubin_log              17.215240        1.078597    15.960766
# ...

# %% [markdown]
# apply descriptive statistics, perform data cleaning and preprocessing . apply feature scaling and  , perform feature selection . build and evaluate a logistic regression model.

# %%
df['Selector'] = df['Selector'].map({1: 0, 2: 1})


y = df['Selector']
X = df.drop(['Age', 'Selector'], axis=1)


X['Albumin_Globulin_Ratio'].fillna(X['Albumin_Globulin_Ratio'].mean(), inplace=True)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Shape of X_train_scaled:", X_train_scaled.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test_scaled:", X_test_scaled.shape)
print("Shape of y_test:", y_test.shape)
print("Missing values in X after imputation:\n", X.isnull().sum())
# Out:
# Shape of X_train_scaled: (408, 14)
# Shape of y_train: (408,)
# Shape of X_test_scaled: (175, 14)
# Shape of y_test: (175,)
# Missing values in X after imputation:
#  Gender                          0
# Total_Bilirubin                 0
# Direct_Bilirubin                0
# Alkaline_Phosphotase            0
# Alamine_Aminotransferase        0
# Aspartate_Aminotransferase      0
# Total_Proteins                  0
# Albumin                         0
# Albumin_Globulin_Ratio          0
# Gender_log                      0
# Total_Bilirubin_log             0
# Direct_Bilirubin_log            0
# Alkaline_Phosphotase_log        0
# Alamine_Aminotransferase_log    0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

log_reg_model = LogisticRegression(random_state=42)
log_reg_model.fit(X_train_scaled, y_train)


y_pred = log_reg_model.predict(X_test_scaled)

# Evaluate the model
print("Logistic Regression Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Logistic Regression Model Evaluation:
# Accuracy: 0.7200
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       128
#            1       0.47      0.34      0.40        47
#
#     accuracy                           0.72       175
#    macro avg       0.63      0.60      0.61       175
# weighted avg       0.70      0.72      0.70       175
#
#
# Confusion Matrix:
#  [[110  18]
#  [ 31  16]]
